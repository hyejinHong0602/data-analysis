# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
dataset = pd.DataFrame(pd.read_csv('creditcard.csv'))

# %%
dataset.tail(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
dataset[dataset.Time.isnull() == True ]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
dataset.Time.isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Name: Time, Length: 284807, dtype: bool

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.656562e-16 -3.444850e-16  2.578648e-16  4.471968e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.687098e-15 -3.666453e-16 -1.220404e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
y = dataset['Class']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
dataset.drop(columns='Class', inplace=True)

# %%
dataset.shape
# Out:
# (284807, 30)

# %%
# 142,400 record for trainning set
# 85,440 records for Testing set
# 56,960 records for validation
X_train = dataset[:142400]
X_test = dataset[142400:227840]
X_val = dataset[227840:]

# %%
X_train.shape
# Out:
# (142400, 30)

# %%
Y_train = y[:142400]
Y_test = y[142400:227840]
Y_val = y[227840:]

# %%
Y_train.shape
# Out:
# (142400,)

# %%
from sklearn.preprocessing import StandardScaler
X_train['Amount'] = StandardScaler().fit_transform(X_train['Amount'].values.reshape (-1,1))
X_test['Amount'] = StandardScaler().fit_transform(X_test['Amount'].values.reshape (-1,1))
X_val['Amount'] = StandardScaler().fit_transform(X_val['Amount'].values.reshape (-1,1))
# Out:
# C:\Users\hhz20\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hhz20\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hhz20\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %%
network = Sequential()

# %%
network.add(layers.Dense(10, activation='relu', kernel_regularizer=l2(0.001), input_shape=(X_train.shape[1],)))
network.add(layers.Dense(8, activation='relu', kernel_regularizer=l2(0.001)))
network.add(layers.Dense(1, activation='sigmoid'))

# %%
network.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
network_history = network.fit(X_train, Y_train, epochs=50, batch_size=500, validation_data=(X_val, Y_val))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# WARNING:tensorflow:From C:\Users\hhz20\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 142400 samples, validate on 56967 samples
# Epoch 1/50
# 142400/142400 [==============================] - 1s 8us/sample - loss: 0.4644 - accuracy: 0.9701 - val_loss: 0.0267 - val_accuracy: 0.9987
# Epoch 2/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0340 - accuracy: 0.9981 - val_loss: 0.0239 - val_accuracy: 0.9987
# Epoch 3/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0325 - accuracy: 0.9981 - val_loss: 0.0234 - val_accuracy: 0.9987
# Epoch 4/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0322 - accuracy: 0.9981 - val_loss: 0.0232 - val_accuracy: 0.9987
# Epoch 5/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0321 - accuracy: 0.9981 - val_loss: 0.0232 - val_accuracy: 0.9987
# Epoch 6/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0232 - val_accuracy: 0.9987
# Epoch 7/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 8/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 9/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 10/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 11/50
# 142400/142400 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.99 - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 12/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 13/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 14/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 15/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 16/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 17/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 18/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 19/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 20/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0231 - val_accuracy: 0.9987
# Epoch 21/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 22/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 23/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0319 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 24/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 25/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 26/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 27/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0230 - val_accuracy: 0.9987
# Epoch 28/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0229 - val_accuracy: 0.9987
# Epoch 29/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0318 - accuracy: 0.9981 - val_loss: 0.0229 - val_accuracy: 0.9987
# Epoch 30/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0317 - accuracy: 0.9981 - val_loss: 0.0229 - val_accuracy: 0.9987
# Epoch 31/50
# 142400/142400 [==============================] - 1s 6us/sample - loss: 0.0317 - accuracy: 0.9981 - val_loss: 0.0229 - val_accuracy: 0.9987
# Epoch 32/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0317 - accuracy: 0.9981 - val_loss: 0.0228 - val_accuracy: 0.9987
# Epoch 33/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0317 - accuracy: 0.9981 - val_loss: 0.0228 - val_accuracy: 0.9987
# Epoch 34/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0316 - accuracy: 0.9981 - val_loss: 0.0228 - val_accuracy: 0.9987
# Epoch 35/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0316 - accuracy: 0.9981 - val_loss: 0.0228 - val_accuracy: 0.9987
# Epoch 36/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0316 - accuracy: 0.9981 - val_loss: 0.0227 - val_accuracy: 0.9987
# Epoch 37/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0316 - accuracy: 0.9981 - val_loss: 0.0227 - val_accuracy: 0.9987
# Epoch 38/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0315 - accuracy: 0.9981 - val_loss: 0.0227 - val_accuracy: 0.9987
# Epoch 39/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0315 - accuracy: 0.9981 - val_loss: 0.0226 - val_accuracy: 0.9987
# Epoch 40/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0314 - accuracy: 0.9981 - val_loss: 0.0226 - val_accuracy: 0.9987
# Epoch 41/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0314 - accuracy: 0.9981 - val_loss: 0.0226 - val_accuracy: 0.9987
# Epoch 42/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0314 - accuracy: 0.9981 - val_loss: 0.0225 - val_accuracy: 0.9987
# Epoch 43/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0313 - accuracy: 0.9981 - val_loss: 0.0225 - val_accuracy: 0.9987
# Epoch 44/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0313 - accuracy: 0.9981 - val_loss: 0.0224 - val_accuracy: 0.9987
# Epoch 45/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0312 - accuracy: 0.9981 - val_loss: 0.0224 - val_accuracy: 0.9987
# Epoch 46/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0312 - accuracy: 0.9981 - val_loss: 0.0223 - val_accuracy: 0.9987
# Epoch 47/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0311 - accuracy: 0.9981 - val_loss: 0.0222 - val_accuracy: 0.9987
# Epoch 48/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0310 - accuracy: 0.9981 - val_loss: 0.0221 - val_accuracy: 0.9987
# Epoch 49/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0309 - accuracy: 0.9981 - val_loss: 0.0221 - val_accuracy: 0.9987
# Epoch 50/50
# 142400/142400 [==============================] - 1s 5us/sample - loss: 0.0308 - accuracy: 0.9981 - val_loss: 0.0220 - val_accuracy: 0.9987

# %%
train_loss = network_history.history['loss']

# %%
val_loss = network_history.history['val_loss']

# %%
epochs = range(1,51)

# %%
plt.plot(epochs, train_loss, 'r', label='Training Loss' )
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and Validation loss Plot.')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network.predict(X_test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
network.evaluate(X_test, Y_test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 85440/85440 [==============================] - 2s 22us/sample - loss: 0.0284 - accuracy: 0.9983
# [0.02838593175964367, 0.99826777]
