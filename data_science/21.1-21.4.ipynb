# %%
from matplotlib import pyplot as plt


data = [("sdsfs",40,60),("sgd",55,55),("dsf",20,15),("sddd",100,15),("adfa",10,15),("bigdata",55,20),("hadoop",60,25)]

def text_size(total: int) -> float:
    return 8 + total / 200*20

for word, job_popularity, resume_popularity in data:
    plt.text(job_popularity, resume_popularity, word, ha='center',va='center',size=text_size(job_popularity + resume_popularity))
    
plt.xlabel("Popularity on job Postings")
plt.ylabel("popularity on resumes")
plt.axis([0,100,0,100])
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
